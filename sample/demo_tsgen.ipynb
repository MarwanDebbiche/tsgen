# %%
from tsgen.generators import cosine, sine, affine

# %%
start = "2020"
end = "2021"
freq = "1D"

ts = sine(start, end, freq, n_periods=11) + affine(start, end, freq, 0, 5)

# %%
ts.plot()

# %% [markdown]
# # Error :

# %%
from tsgen.generators import cosine

# %%
start = "2020"
end = "2021"
freq = "1D"

ts = cosine(start, end, freq, n_periods=11)

# %%
(ts + 10).plot()

# %%
(10 + ts).plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5733a21f2631> in <module>
# ----> 1 (10 + ts).plot()
#
# TypeError: unsupported operand type(s) for +: 'int' and 'TimeSerie'
